# %% [markdown]
# <a href="https://colab.research.google.com/github/asaphkalala/machine-learning/blob/main/machine_learning_coursework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# Load CSV file into a Pandas dataframe
data = pd.read_csv("/content/drive/My Drive/datcw_na.csv")

# Preview the first 5 rows of the dataframe
data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    X0    X1      X2      X3      X4    X5    X6   X7   X8      Y
# 0  C3  1.19  622.55     NaN   89.31  7.00  1.98  0.0  0.0  15.55
# 1  C1  1.19  622.55  323.40  109.15  7.70  3.00  0.0  0.0  15.55
# 2  C1  0.88  463.05  291.06   99.23  5.67  4.40  0.0  0.0  15.55
# 3  C2  0.79  509.36  291.06  121.28  6.30  4.05  0.0  0.0  15.55
# 4  C1  0.89  507.15  385.39  121.28  7.70  2.00  0.0  0.0  20.84
